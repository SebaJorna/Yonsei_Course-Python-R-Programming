# %%
#Assignment 7 
import pandas as pd
import numpy as np

# %%
cd C:\Users\sebas\Desktop\AAU Masterstudium\Semester abroad - Seoul\Yonsei University\Spring Semester 2019\Final Courses\R and Python Programming\Assignments
# Out:
# C:\Users\sebas\Desktop\AAU Masterstudium\Semester abroad - Seoul\Yonsei University\Spring Semester 2019\Final Courses\R and Python Programming\Assignments

# %%
pwd
# Out:
# 'C:\\Users\\sebas\\Desktop\\AAU Masterstudium\\Semester abroad - Seoul\\Yonsei University\\Spring Semester 2019\\Final Courses\\R and Python Programming\\Assignments'

# %%
#1 Read this data and create a DataFrame object called ‘world’. Make sure that the variable ‘country’ is the index, and the labels in the first row of data is the columns of the DataFrame. Also, make sure ‘gdppcap08’ and ‘polityIV’ are both stored in np.float64 type.

world = pd.read_csv('C:\\Users\\sebas\\Desktop\\AAU Masterstudium\\Semester abroad - Seoul\\Yonsei University\\Spring Semester 2019\\Final Courses\\R and Python Programming\\Assignments\\world_small.csv',index_col='country', header=0, dtype={'gdppcap08' :np.float64})
world
# Out:
#                                 region  gdppcap08   polityIV
# country
# Albania                     C&E Europe     7715.0  17.800000
# Algeria                         Africa     8033.0  10.000000
# Angola                          Africa     5899.0   8.000000
# Argentina                   S. America    14333.0  18.000000
# Armenia                     C&E Europe     6070.0  15.000000
# Australia                 Asia-Pacific    35677.0  20.000000
# Austria                      W. Europe    38152.0  20.000000
# Azerbaijan                  C&E Europe     8765.0   3.000000
# Bahrain                    Middle East    34605.0   3.000000
# Bangladesh                Asia-Pacific     1334.0  16.000000
# Belarus                     C&E Europe    12261.0   3.000000
# Belgium                      W. Europe    34493.0  20.000000
# Benin                           Africa     1468.0  16.200000
# Bhutan                    Asia-Pacific     4755.0   2.000000
# ...

# %%
#2 Select only the countries with their ‘polityIV’ are in the bottom 10% and save their information as a DataFrame called btm10
btm10 = world[world['polityIV']<10]
btm10
# Out:
#                          region  gdppcap08  polityIV
# country
# Angola                   Africa     5899.0  8.000000
# Azerbaijan           C&E Europe     8765.0  3.000000
# Bahrain             Middle East    34605.0  3.000000
# Belarus              C&E Europe    12261.0  3.000000
# Bhutan             Asia-Pacific     4755.0  2.000000
# Cameroon                 Africa     2215.0  6.000000
# Chad                     Africa     1455.0  8.000000
# China              Asia-Pacific     5962.0  3.000000
# Congo Brazzaville        Africa     3946.0  6.000000
# Cuba                 S. America     9500.0  3.000000
# Egypt               Middle East     5416.0  4.000000
# Equatorial Guinea        Africa    33873.0  5.000000
# Eritrea                  Africa      632.0  3.000000
# Gabon                    Africa    14527.0  6.000000
# Gambia                   Africa     1363.0  5.000000
# Guinea                   Africa     1204.0  9.000000
# Haiti                S. America     1177.0  8.000000
# ...

# %%
#3 Select only the countries with their ‘polityIV’ are in the bottom 10% and save their information as a DataFrame called btm10

afr= pd.DataFrame(world.loc[world.region=='Africa','polityIV'])
afr
# Out:
#                            polityIV
# country
# Algeria                   10.000000
# Angola                     8.000000
# Benin                     16.200000
# Botswana                  19.000000
# Burkina Faso              10.000000
# Cameroon                   6.000000
# Central African Republic  10.200000
# Chad                       8.000000
# Comoros                   15.800000
# Congo Brazzaville          6.000000
# Congo Kinshasa            15.000000
# Djibouti                  12.000000
# Equatorial Guinea          5.000000
# Eritrea                    3.000000
# Gabon                      6.000000
# Gambia                     5.000000
# Ghana                     16.666667
# Guinea                     9.000000
# Guinea-Bissau             11.000000
# Kenya                     18.000000
# Lesotho                   18.000000
# Liberia                   10.000000
# Madagascar                17.000000
# Malawi                    15.000000
# Mali                      16.000000
# ...

# %%
#4 print the row indices of the countries in S. America. Use np.nonzero.

# %%
#5 The following 3 expressions are for selecting the last two columns (‘gdppcap08’ and ‘polityIV’). Fill the blanks.

world[['gdppcap08', 'polityIV']]
# Out:
#                           gdppcap08   polityIV
# country
# Albania                      7715.0  17.800000
# Algeria                      8033.0  10.000000
# Angola                       5899.0   8.000000
# Argentina                   14333.0  18.000000
# Armenia                      6070.0  15.000000
# Australia                   35677.0  20.000000
# Austria                     38152.0  20.000000
# Azerbaijan                   8765.0   3.000000
# Bahrain                     34605.0   3.000000
# Bangladesh                   1334.0  16.000000
# Belarus                     12261.0   3.000000
# Belgium                     34493.0  20.000000
# Benin                        1468.0  16.200000
# Bhutan                       4755.0   2.000000
# Bolivia                      4278.0  18.200000
# Botswana                    13392.0  19.000000
# Brazil                      10296.0  18.000000
# Bulgaria                    12393.0  19.000000
# Burkina Faso                 1161.0  10.000000
# ...

# %%
#5 (2) 
world.iloc[:, 1:]
# Out:
#                           gdppcap08   polityIV
# country
# Albania                      7715.0  17.800000
# Algeria                      8033.0  10.000000
# Angola                       5899.0   8.000000
# Argentina                   14333.0  18.000000
# Armenia                      6070.0  15.000000
# Australia                   35677.0  20.000000
# Austria                     38152.0  20.000000
# Azerbaijan                   8765.0   3.000000
# Bahrain                     34605.0   3.000000
# Bangladesh                   1334.0  16.000000
# Belarus                     12261.0   3.000000
# Belgium                     34493.0  20.000000
# Benin                        1468.0  16.200000
# Bhutan                       4755.0   2.000000
# Bolivia                      4278.0  18.200000
# Botswana                    13392.0  19.000000
# Brazil                      10296.0  18.000000
# Bulgaria                    12393.0  19.000000
# Burkina Faso                 1161.0  10.000000
# ...

# %%
#5 (3)
world.loc[:,['gdppcap08','polityIV']]
# Out:
#                           gdppcap08   polityIV
# country
# Albania                      7715.0  17.800000
# Algeria                      8033.0  10.000000
# Angola                       5899.0   8.000000
# Argentina                   14333.0  18.000000
# Armenia                      6070.0  15.000000
# Australia                   35677.0  20.000000
# Austria                     38152.0  20.000000
# Azerbaijan                   8765.0   3.000000
# Bahrain                     34605.0   3.000000
# Bangladesh                   1334.0  16.000000
# Belarus                     12261.0   3.000000
# Belgium                     34493.0  20.000000
# Benin                        1468.0  16.200000
# Bhutan                       4755.0   2.000000
# Bolivia                      4278.0  18.200000
# Botswana                    13392.0  19.000000
# Brazil                      10296.0  18.000000
# Bulgaria                    12393.0  19.000000
# Burkina Faso                 1161.0  10.000000
# ...

# %%
#6 Replace all the ‘polityIV’ values which are greater than or equal to 20 as NaN.

pd.read_csv('world', na_values=['polityIV']>=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-8a96edeba72c> in <module>
#       1 #6 Replace all the ‘polityIV’ values which are greater than or equal to 20 as NaN.
#       2
# ----> 3 pd.read_csv('world', na_values=['polityIV']>=20)
#
# TypeError: '>=' not supported between instances of 'list' and 'int'
